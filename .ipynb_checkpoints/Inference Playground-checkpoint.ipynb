# %%
import torch
import cv2
from matplotlib import pyplot as plt

from loss.loss_discriminator import *
from loss.loss_generator import *
from network.blocks import *
from network.model import *
from webcam_demo.webcam_extraction_conversion import *

from params.params import path_to_chkpt
from tqdm import tqdm

#from dataset.video_extraction_conversion import *

# %%
"""Init"""

#Paths
path_to_model_weights = 'model_weights.tar'

path_to_embedding = 'e_hat_images.tar'
path_to_embedding = 'e_hat_images_new.tar'
path_to_model_weights = 'finetuned_model.tar'
path_to_mp4 = 'test_vid2.webm'
path_to_mp4 = 'examples/fine_tuning/test_video.mp4'

device = torch.device("cuda:0")
cpu = torch.device("cpu")

checkpoint = torch.load(path_to_model_weights, map_location=cpu) 
e_hat = torch.load(path_to_embedding, map_location=cpu)
e_hat = e_hat['e_hat'].to(device)

G = Generator(256, finetuning=True, e_finetuning=e_hat)
#G = Generator(256, finetuning=False)


"""Training Init"""
G.load_state_dict(checkpoint['G_state_dict'])
G.to(device)
G.eval()
# Out:
# Generator(
#   (sigmoid): Sigmoid()
#   (pad): Padding(
#     (zero_pad): ZeroPad2d(padding=(0, 0, 0, 0), value=0.0)
#   )
#   (resDown1): ResBlockDown(
#     (relu): ReLU()
#     (relu_inplace): ReLU(inplace=True)
#     (avg_pool2d): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (conv_l1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(3, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (conv_r2): Conv2d(64, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#   )
#   (in1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (resDown2): ResBlockDown(
#     (relu): ReLU()
#     (relu_inplace): ReLU(inplace=True)
#     (avg_pool2d): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (conv_l1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (in2): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (resDown3): ResBlockDown(
#     (relu): ReLU()
#     (relu_inplace): ReLU(inplace=True)
#     (avg_pool2d): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (conv_l1): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (in3): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (self_att_Down): SelfAttention(
#     (conv_f): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#     (conv_g): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#     (conv_h): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-2)
#   )
#   (resDown4): ResBlockDown(
#     (relu): ReLU()
#     (relu_inplace): ReLU(inplace=True)
#     (avg_pool2d): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (conv_l1): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (in4): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (resDown5): ResBlockDown(
#     (relu): ReLU()
#     (relu_inplace): ReLU(inplace=True)
#     (avg_pool2d): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (conv_l1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (in5): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (resDown6): ResBlockDown(
#     (relu): ReLU()
#     (relu_inplace): ReLU(inplace=True)
#     (avg_pool2d): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     (conv_l1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (in6): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#   (res1): ResBlock(
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (res2): ResBlock(
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (res3): ResBlock(
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (res4): ResBlock(
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (res5): ResBlock(
#     (relu): ReLU(inplace=True)
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resUp1): ResBlockUp(
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (relu): ReLU(inplace=True)
#     (conv_l1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resUp2): ResBlockUp(
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (relu): ReLU(inplace=True)
#     (conv_l1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resUp3): ResBlockUp(
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (relu): ReLU(inplace=True)
#     (conv_l1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resUp4): ResBlockUp(
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (relu): ReLU(inplace=True)
#     (conv_l1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (self_att_Up): SelfAttention(
#     (conv_f): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#     (conv_g): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#     (conv_h): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     (softmax): Softmax(dim=-2)
#   )
#   (resUp5): ResBlockUp(
#     (upsample): Upsample(scale_factor=2.0, mode=nearest)
#     (relu): ReLU(inplace=True)
#     (conv_l1): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv_r2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (resUp6): ResBlockUp(
#     (upsample): Upsample(size=(256, 256), mode=nearest)
#     (relu): ReLU(inplace=True)
#     (conv_l1): Conv2d(64, 3, kernel_size=(1, 1), stride=(1, 1))
#     (conv_r1): Conv2d(64, 3, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (conv_r2): Conv2d(3, 3, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#   )
# )

# %%
img = cv2.imread('examples/fine_tuning/test_images/test_cranston.jpeg')
res = generate_cropped_landmarks([img], pad=50)
g_y = res[0][1]
print(g_y.shape)
#g_y = torch.from_numpy(g_y).transpose(2,4)
#frame_mark_images = torch.from_numpy(np.array(frame_mark_images)).type(dtype = torch.float) #1,2,256,256,3
#frame_mark_images = frame_mark_images.transpose(2,4).to(self.device) #1,2,3,256,256
plt.imshow(g_y)
# Out:
# (256, 256, 3)

# %%
generate_landmarks
# Out:
# <function webcam_demo.webcam_extraction_conversion.generate_landmarks(cap, device, pad)>

# %%
t2 = generate_landmarks([img], pad=50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d97787c6d5c7> in <module>
# ----> 1 t2 = generate_landmarks([img], pad=50)
#
# TypeError: generate_landmarks() missing 1 required positional argument: 'device'

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
g_yy = torch.transpose(torch.from_numpy(g_y),0,2).view(1,3,256,256).type(torch.float).to(device)
# Out:
# /home/zhaoy/anaconda3/envs/fewshot/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629427478/work/torch/csrc/utils/tensor_numpy.cpp:141.)
#   """Entry point for launching an IPython kernel.

# %%
g_yy.shape
# Out:
# torch.Size([1, 3, 256, 256])

# %%
g_yy.dtype
# Out:
# torch.float32

# %%
x_hat = G(g_yy, e_hat)

# %%
x_hat.shape
# Out:
# torch.Size([1, 3, 256, 256])

# %%
xxx = x_hat.detach().cpu().squeeze()
xxx = torch.transpose(xxx,0,2)
xxx.shape
plt.imshow(xxx/255)

# %%
cap = cv2.VideoCapture(path_to_mp4)
print(cap)
n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
ret = True
i = 0
size = (256*3,256)
#out = cv2.VideoWriter('project.mp4',cv2.VideoWriter_fourcc('M','P','4','2'), 30, size)
video = cv2.VideoWriter('project.mp4',cv2.VideoWriter_fourcc(*'DIVX'), fps, size)
# Out:
# <VideoCapture 0x7f52280add70>

# %%
with torch.no_grad():
    for qq in range(1):
        x, g_y, ret = generate_landmarks(cap=cap, device=device, pad=50)
        g_y = g_y.unsqueeze(0)/255
        x = x.unsqueeze(0)/255


        #forward
        # Calculate average encoding vector for video
        #f_lm_compact = f_lm.view(-1, f_lm.shape[-4], f_lm.shape[-3], f_lm.shape[-2], f_lm.shape[-1]) #BxK,2,3,224,224
        #train G

        x_hat = G(g_y, e_hat)

        plt.clf()
        out1 = x_hat.transpose(1,3)[0]
        #for img_no in range(1,x_hat.shape[0]):
        #    out1 = torch.cat((out1, x_hat.transpose(1,3)[img_no]), dim = 1)
        out1 = out1.to(cpu).numpy()
        #plt.imshow(out1)
        #plt.show()

        #plt.clf()
        out2 = x.transpose(1,3)[0]
        #for img_no in range(1,x.shape[0]):
        #    out2 = torch.cat((out2, x.transpose(1,3)[img_no]), dim = 1)
        out2 = out2.to(cpu).numpy()
        #plt.imshow(out2)
        #plt.show()

        #plt.clf()
        out3 = g_y.transpose(1,3)[0]
        #for img_no in range(1,g_y.shape[0]):
        #    out3 = torch.cat((out3, g_y.transpose(1,3)[img_no]), dim = 1)
        out3 = out3.to(cpu).numpy()
        #plt.imshow(out3)
        #plt.show()

        fake = cv2.cvtColor(out1*255, cv2.COLOR_BGR2RGB)
        me = cv2.cvtColor(out2*255, cv2.COLOR_BGR2RGB)
        landmark = cv2.cvtColor(out3*255, cv2.COLOR_BGR2RGB)
        img = np.concatenate((me, landmark, fake), axis=1)
        img = img.astype('uint8')
        #video.write(img)

        i+=1
        print(i,'/',n_frames)
#cap.release()
#video.release()
"""cv2.destroyAllWindows()"""
# Out:
# True
# 1 / 100
# 'cv2.destroyAllWindows()'

# %%
plt.imshow(img)

# %%
g_y.shape
# Out:
# torch.Size([1, 3, 256, 256])

# %%
g_y.dtype
# Out:
# torch.float32

# %%
x2 = G(g_yy,x_hat)
x2 = x2.detach().cpu().squeeze()
x2 = torch.transpose(x2,0,2)
plt.imshow(x2/255)

# %%
x = G(g_y,x_hat)
x = x.detach().cpu().squeeze()
x = torch.transpose(x,0,2)
plt.imshow(x/255)

# %%
# !nvidia-smi
# Out:
# Thu Oct 29 11:35:15 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 455.23.05    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 207...  On   | 00000000:26:00.0  On |                  N/A |
# | 32%   30C    P8    12W / 215W |    493MiB /  7974MiB |      3%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1101      G   /usr/lib/xorg/Xorg                 35MiB |
# |    0   N/A  N/A     68462      G   /usr/lib/xorg/Xorg                235MiB |
# |    0   N/A  N/A     68590      G   /usr/bin/gnome-shell               98MiB |
# |    0   N/A  N/A     69375      G   ...token=4112610474890165081        4MiB |
# |    0   N/A  N/A     70042      G   ...AAAAAAAAA= --shared-files       75MiB |
# |    0   N/A  N/A     72103      G   gnome-control-center                2MiB |
# |    0   N/A  N/A     72878      G   ...AAAAAAAAA= --shared-files       10MiB |
# |    0   N/A  N/A     75739      G   ...AAAAAAAAA= --shared-files       12MiB |
# +-----------------------------------------------------------------------------+

# %%
import zipfile

# %%
import os
zipdir = '/media/zhaoy/New Volume/Zhao Yue/dataset/voxceleb2'
os.listdir(zipdir)
# Out:
# ['vox2_aac.zip', 'vox2_mp4.zip']

# %%
archive = zipfile.ZipFile(zipdir+'/vox2_mp4.zip')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7
#  'dev/mp4/id07876/poyWqutsXvU/00089.mp4',
#  'dev/mp4/id07876/poyWqutsXvU/00091.mp4',
#  'dev/mp4/id07876/poyWqutsXvU/00078.mp4',
#  'dev/mp4/id07876/poyWqutsXvU/00081.mp4',
#  'dev/mp4/id07876/poyWqutsXvU/00080.mp4',
#  'dev/mp4/id07876/poyWqutsXvU/00082.mp4',
#  'dev/mp4/id07876/poyWqutsXvU/00084.mp4',
#  'dev/mp4/id07876/poyWqutsXvU/00086.mp4',
#  'dev/mp4/id07876/9FsTYcMKt4w/',
#  'dev/mp4/id07876/9FsTYcMKt4w/00013.mp4',
#  'dev/mp4/id07876/9FsTYcMKt4w/00014.mp4',
#  'dev/mp4/id07876/9FsTYcMKt4w/00010.mp4',
#  'dev/mp4/id07876/9FsTYcMKt4w/00011.mp4',
#  'dev/mp4/id07876/9FsTYcMKt4w/00012.mp4',
#  'dev/mp4/id07876/emjBVdXapIk/',
#  'dev/mp4/id07876/emjBVdXapIk/00065.mp4',
#  'dev/mp4/id07876/emjBVdXapIk/00064.mp4',
#  'dev/mp4/id07876/WLcN5j2jokA/',
#  'dev/mp4/id07876/WLcN5j2jokA/00051.mp4',
#  'dev/mp4/id07876/WLcN5j2jokA/00050.mp4',
#  'dev/mp4/id07876/WLcN5j2jokA/00052.mp4',
#  'dev/mp4/id07876/WLcN5j2jokA/00049.mp4',
#  'dev/mp4/id07876/Yu-VWZNUctw/',
#  'dev/mp4/id07876/Yu-VWZNUctw/00053.mp4',
#  'dev/mp4/id07876/Yu-VWZNUctw/00054.mp4',
#  'dev/mp4/id07876/HIrjEZezHEE/',
#  'dev/mp4/id07876/HIrjEZezHEE/00030.mp4',
#  'dev/mp4/id07876/4rYrvDHpA9I/',
#  'dev/mp4/id07876/4rYrvDHpA9I/00002.mp4',
#  'dev/mp4/id07876/4rYrvDHpA9I/00004.mp4',
#  'dev/mp4/id07876/4rYrvDHpA9I/00003.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/',
#  'dev/mp4/id07876/Snop6dEWhZs/00039.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/00043.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/00041.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/00046.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/00045.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/00038.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/00048.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/00042.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/00044.mp4',
#  'dev/mp4/id07876/Snop6dEWhZs/00047.mp4',
#  ...]

# %%
vid = archive.read('dev/mp4/id05668/d_qVAG39Ewo/00067.mp4')

# %%
import cv2
cv2.VideoCapture(vid)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-74a41ec55ee3> in <module>
#       1 import cv2
# ----> 2 cv2.VideoCapture(vid)
#
# TypeError: Argument 'index' is required to be an integer

# %%
with zipfile.ZipFile(zipdir+'/vox2_mp4.zip','r') as zipObj:
    zipObj.extract(listFiles[1234])

# %%
import torch
import cv2
from matplotlib import pyplot as plt

from loss.loss_discriminator import *
from loss.loss_generator import *
from network.blocks import *
from network.model import *
from webcam_demo.webcam_extraction_conversion import *

from params.params import path_to_chkpt
from tqdm import tqdm

"""Init"""

#Paths
path_to_model_weights = 'model_weights.tar'

path_to_embedding = 'e_hat_images.tar'
#path_to_embedding = 'e_hat_images_new.tar'
path_to_model_weights = 'finetuned_model.tar'
path_to_mp4 = 'test_vid2.webm'
path_to_mp4 = 'examples/fine_tuning/test_video.mp4'
path_to_mp4 = 'dev/00026.mp4'

device = torch.device("cuda:0")
cpu = torch.device("cpu")

checkpoint = torch.load(path_to_model_weights, map_location=cpu) 
e_hat = torch.load(path_to_embedding, map_location=cpu)
e_hat = e_hat['e_hat'].to(device)

G = Generator(256, finetuning=True, e_finetuning=e_hat)
#G = Generator(256, finetuning=False)


"""Training Init"""
G.load_state_dict(checkpoint['G_state_dict'])
G.to(device)
G.eval()

"""Main"""
print('PRESS Q TO EXIT')
cap = cv2.VideoCapture(path_to_mp4)
print(cap)
n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
ret = True
i = 0
size = (256*3,256)
#out = cv2.VideoWriter('project.mp4',cv2.VideoWriter_fourcc('M','P','4','2'), 30, size)
video = cv2.VideoWriter('project.mp4',cv2.VideoWriter_fourcc(*'DIVX'), fps, size)

with torch.no_grad():
    while ret:
        x, g_y, ret = generate_landmarks(cap=cap, device=device, pad=50)
        if ret:
            g_y = g_y.unsqueeze(0)/255
            x = x.unsqueeze(0)/255


            #forward
            # Calculate average encoding vector for video
            #f_lm_compact = f_lm.view(-1, f_lm.shape[-4], f_lm.shape[-3], f_lm.shape[-2], f_lm.shape[-1]) #BxK,2,3,224,224
            #train G

            x_hat = G(g_y, e_hat)

            plt.clf()
            out1 = x_hat.transpose(1,3)[0]
            #for img_no in range(1,x_hat.shape[0]):
            #    out1 = torch.cat((out1, x_hat.transpose(1,3)[img_no]), dim = 1)
            out1 = out1.to(cpu).numpy()#.squeeze()

            #plt.imshow(out1)
            #plt.show()

            #plt.clf()
            out2 = x.transpose(1,3)[0]
            #for img_no in range(1,x.shape[0]):
            #    out2 = torch.cat((out2, x.transpose(1,3)[img_no]), dim = 1)
            out2 = out2.to(cpu).numpy()
            #plt.imshow(out2)
            #plt.show()

            #plt.clf()
            out3 = g_y.transpose(1,3)[0]
            #for img_no in range(1,g_y.shape[0]):
            #    out3 = torch.cat((out3, g_y.transpose(1,3)[img_no]), dim = 1)
            out3 = out3.to(cpu).numpy()
            #plt.imshow(out3)
            #plt.show()

            fake = cv2.cvtColor(out1, cv2.COLOR_BGR2RGB)
            me = cv2.cvtColor(out2*255, cv2.COLOR_BGR2RGB)
            landmark = cv2.cvtColor(out3*255, cv2.COLOR_BGR2RGB)
            img = np.concatenate((me, landmark, fake), axis=1)
            img = img.astype('uint8')
            video.write(img)

            i+=1
            print(i,'/',n_frames)
cap.release()
video.release()
"""cv2.destroyAllWindows()"""
